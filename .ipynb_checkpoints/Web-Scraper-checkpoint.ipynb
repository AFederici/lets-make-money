# %%
from bs4 import BeautifulSoup
import urllib
import datetime
import pandas as pd
import string
# Get a <tr> tag with a specific class
#soup.find('tr', {'class': 'some-css-class'})

# Get element's specific attribute value
#soup.find('a', {'class': 'some-css-class'}).get('href')

# Find image's src attribute for example
#soup.find('img', {'class': 'img-responsive'}).get('src')

# Check if element has some attribute (returns True or False)
#soup.find('div').has_attr('style') 
def clean_data(self, data):
        data = data.fillna(method = 'ffill')
        data = data.fillna(method = 'bfill')
        data = data.groupby('datetime').mean()
        #for ind, rows in data.iterrows():
        #    price1 = rows['open']
        #    price2 = rows['close']
            #print("{:.2f} {:.2f}".format(price1, price2))
        return data
            
def strp(s):
    exclude = set(string.punctuation)
    x = ''.join(ch for ch in s if ch not in exclude)
    return datetime.datetime.strptime(x, '%b %d %Y')
def strp2(s):
    return s.strftime("%D")
def name_from_url(url):
    c = 0
    i = 0
    txt = ''
    while(c != '/'):
        c = url[37 + i]
        i += 1
        txt += c
    txt = txt[:-1]
    return txt

def scrape(url):
    r = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(r, 'lxml')
    entries = []
    rows = soup.find_all("tr") # returns an array of <tr> objects
    for row in rows:
        cols = row.find_all("td")
        if len(cols) > 0:
            entry = {
                "time": cols[0].get_text(),
                "open": float(cols[1].get_text()),
                "close": float(cols[4].get_text())
            }
            entries.append(entry)

    df = pd.DataFrame(entries)
    df['date'] = df['time'].apply(strp)
    df['date2'] = df['date'].apply(strp2)
    df['norm'] = 1.0 * df['close'] / df['close'][0]
    for ind, row in df.iterrows():
        if row['open'] > row['close']:
            row['bool'] = 1 
        else:
            row['bool'] = 0 
    print(df)
    df.to_csv(name_from_url(url) + ".csv")
    
def normalize(series, first):
    return 1.0 * series / first
#20171226
#20180326
def url_make(company, start, end):
    return 'https://coinmarketcap.com/currencies/' + company + '/historical-data/?start=' + start + '&end=' + end


def set_baseline(self, baseline, relative): # feed in as np arrays
        # Print out normalized prices
        #relative = np.asarray(relative)
        #baseline = np.asarray(baseline)
        relative = 1.0 * (relative - baseline) / baseline
        baseline = np.zeros([baseline.shape[0]])
        #baseline = baseline.tolist()
        return relative
        #pass baseline in by value??
        
def compute_correlations(self, eth, golem, neo):
        print("%.5f" % np.corrcoef(eth, golem)[0][1])
        print("%.5f" % np.corrcoef(eth, neo)[0][1])
        print("%.5f" % np.corrcoef( golem, neo)[0][1])
        
        
url_t = url_make('neo', '20171026', '20180326')
scrape(url_t)
# Out:
#       close    open          time       date     date2      norm
# 0     59.74   65.40  Mar 26, 2018 2018-03-26  03/26/18  1.000000
# 1     65.43   65.19  Mar 25, 2018 2018-03-25  03/25/18  1.095246
# 2     65.73   69.07  Mar 24, 2018 2018-03-24  03/24/18  1.100268
# 128   42.74   39.74  Nov 18, 2017 2017-11-18  11/18/17  0.715434
# 129   40.50   28.71  Nov 17, 2017 2017-11-17  11/17/17  0.677938
# 130   28.70   29.45  Nov 16, 2017 2017-11-16  11/16/17  0.480415
# 131   29.35   29.79  Nov 15, 2017 2017-11-15  11/15/17  0.491296
# 132   29.73   28.40  Nov 14, 2017 2017-11-14  11/14/17  0.497657
# 133   28.40   27.12  Nov 13, 2017 2017-11-13  11/13/17  0.475393
# 134   26.96   28.44  Nov 12, 2017 2017-11-12  11/12/17  0.451289
# 135   28.53   28.15  Nov 11, 2017 2017-11-11  11/11/17  0.477569
# 136   28.18   31.97  Nov 10, 2017 2017-11-10  11/10/17  0.471711
# 137   31.90   30.76  Nov 09, 2017 2017-11-09  11/09/17  0.533981
# 138   30.67   26.17  Nov 08, 2017 2017-11-08  11/08/17  0.513391
# 139   26.23   26.26  Nov 07, 2017 2017-11-07  11/07/17  0.439069
# 140   26.32   26.47  Nov 06, 2017 2017-11-06  11/06/17  0.440576
# 141   26.38   26.48  Nov 05, 2017 2017-11-05  11/05/17  0.441580
# 142   26.49   26.77  Nov 04, 2017 2017-11-04  11/04/17  0.443421
# 143   26.82   24.60  Nov 03, 2017 2017-11-03  11/03/17  0.448945
# 144   24.50   26.75  Nov 02, 2017 2017-11-02  11/02/17  0.410110
# 145   26.86   28.38  Nov 01, 2017 2017-11-01  11/01/17  0.449615
# 146   28.47   28.69  Oct 31, 2017 2017-10-31  10/31/17  0.476565
# 147   28.79   27.72  Oct 30, 2017 2017-10-30  10/30/17  0.481922
# 148   27.76   27.20  Oct 29, 2017 2017-10-29  10/29/17  0.464680
# 149   27.35   28.86  Oct 28, 2017 2017-10-28  10/28/17  0.457817
# 150   28.76   28.33  Oct 27, 2017 2017-10-27  10/27/17  0.481419
# 151   28.33   28.48  Oct 26, 2017 2017-10-26  10/26/17  0.474222
#
# [152 rows x 6 columns]

# %%
from matplotlib import style
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.finance import candlestick_ohlc
import matplotlib.dates as mdates
import pandas_datareader.data as web
style.use('ggplot')
#start time
#end time
df = web.DataReader('TSLA', 'yahoo', start, end)
df.to_csv('tsla.csv')
df = pd.read_csv('tsla.csv', parse_date = True, index_col = 0)

def candlsticks(df):
    df_ohlc = df['Adj Close'].resample('10D').ohlc()
    df_volume = df['Volume'].resampe('10D').sum()
    df_ohlc.reset_index(inplace = True)
    df_ohlc['Date'] = df_ohlc['Date'].map(mdates.date2num)
    ax1.xaxis_date()
    ax1 = plt.subplot2grid((6,1), (0,0), rowspan = 5, colspan = 1)
    ax2 = plt.subplot2grid((6,1), (5,0), rowspan = 1, colspan = 1, sharex = ax1)
    candlestick_ohlc(ax1, df_ohlc.values, width = 2, colorup = 'g')
    ax2.fill_between(df_volum.index.map(mdates.date2num), df_volume.values, 0)
    plt.show()
